# %%
import matplotlib.pyplot as plt

# Plot the filtered data
plt.figure(figsize=(10, 6))
plt.plot(filtered_data['value_time'], filtered_data['value'])
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Forecast Data')
plt.grid(True)
plt.show()

# %%
forecast_data
# Out:
#             reference_time          value_time  nwm_feature_id  value  \
# 0      2023-04-30 12:00:00 2023-04-30 13:00:00            3109   2.41
# 1      2023-04-30 12:00:00 2023-04-30 14:00:00            3109   2.41
# 2      2023-04-30 12:00:00 2023-04-30 15:00:00            3109   2.41
# 3      2023-04-30 12:00:00 2023-04-30 16:00:00            3109   2.36
# 4      2023-04-30 12:00:00 2023-04-30 17:00:00            3109   2.36
# ...                    ...                 ...             ...    ...
# 223827 2023-04-30 12:00:00 2023-05-01 12:00:00      1180000535   2.47
# 223828 2023-04-30 12:00:00 2023-05-01 13:00:00      1180000535   2.47
# 223829 2023-04-30 12:00:00 2023-05-01 14:00:00      1180000535   2.47
# 223830 2023-04-30 12:00:00 2023-05-01 15:00:00      1180000535   2.48
# 223831 2023-04-30 12:00:00 2023-05-01 16:00:00      1180000535   2.48
#
#        usgs_site_code          configuration measurement_unit variable_name
# 0            01030350  analysis_assim_extend             m3/s    streamflow
# 1            01030350  analysis_assim_extend             m3/s    streamflow
# 2            01030350  analysis_assim_extend             m3/s    streamflow
# 3            01030350  analysis_assim_extend             m3/s    streamflow
# 4            01030350  analysis_assim_extend             m3/s    streamflow
# ...               ...                    ...              ...           ...
# 223827       10254970  analysis_assim_extend             m3/s    streamflow
# 223828       10254970  analysis_assim_extend             m3/s    streamflow
# 223829       10254970  analysis_assim_extend             m3/s    streamflow
# 223830       10254970  analysis_assim_extend             m3/s    streamflow
# 223831       10254970  analysis_assim_extend             m3/s    streamflow
#
# [1566824 rows x 8 columns]

# %%
filtered_data
# Out:
#            reference_time          value_time  nwm_feature_id      value  \
# 75544 2023-04-30 12:00:00 2023-04-30 13:00:00         7086109  11.690000
# 75545 2023-04-30 12:00:00 2023-04-30 14:00:00         7086109  11.640000
# 75546 2023-04-30 12:00:00 2023-04-30 15:00:00         7086109  11.640000
# 75547 2023-04-30 12:00:00 2023-04-30 16:00:00         7086109  11.580000
# 75548 2023-04-30 12:00:00 2023-04-30 17:00:00         7086109  11.580000
# ...                   ...                 ...             ...        ...
# 75567 2023-04-30 12:00:00 2023-05-01 12:00:00         7086109  11.100000
# 75568 2023-04-30 12:00:00 2023-05-01 13:00:00         7086109  11.040000
# 75569 2023-04-30 12:00:00 2023-05-01 14:00:00         7086109  10.990000
# 75570 2023-04-30 12:00:00 2023-05-01 15:00:00         7086109  10.929999
# 75571 2023-04-30 12:00:00 2023-05-01 16:00:00         7086109  10.930000
#
#       usgs_site_code          configuration measurement_unit variable_name
# 75544       05106000  analysis_assim_extend             m3/s    streamflow
# 75545       05106000  analysis_assim_extend             m3/s    streamflow
# 75546       05106000  analysis_assim_extend             m3/s    streamflow
# 75547       05106000  analysis_assim_extend             m3/s    streamflow
# 75548       05106000  analysis_assim_extend             m3/s    streamflow
# ...              ...                    ...              ...           ...
# 75567       05106000  analysis_assim_extend             m3/s    streamflow
# 75568       05106000  analysis_assim_extend             m3/s    streamflow
# 75569       05106000  analysis_assim_extend             m3/s    streamflow
# 75570       05106000  analysis_assim_extend             m3/s    streamflow
# 75571       05106000  analysis_assim_extend             m3/s    streamflow
#
# [196 rows x 8 columns]

# %%
filtered_data
# Out:
#            reference_time          value_time  nwm_feature_id      value  \
# 75544 2023-04-30 12:00:00 2023-04-30 13:00:00         7086109  11.690000
# 75545 2023-04-30 12:00:00 2023-04-30 14:00:00         7086109  11.640000
# 75546 2023-04-30 12:00:00 2023-04-30 15:00:00         7086109  11.640000
# 75547 2023-04-30 12:00:00 2023-04-30 16:00:00         7086109  11.580000
# 75548 2023-04-30 12:00:00 2023-04-30 17:00:00         7086109  11.580000
# ...                   ...                 ...             ...        ...
# 75567 2023-04-30 12:00:00 2023-05-01 12:00:00         7086109  11.100000
# 75568 2023-04-30 12:00:00 2023-05-01 13:00:00         7086109  11.040000
# 75569 2023-04-30 12:00:00 2023-05-01 14:00:00         7086109  10.990000
# 75570 2023-04-30 12:00:00 2023-05-01 15:00:00         7086109  10.929999
# 75571 2023-04-30 12:00:00 2023-05-01 16:00:00         7086109  10.930000
#
#       usgs_site_code          configuration measurement_unit variable_name
# 75544       05106000  analysis_assim_extend             m3/s    streamflow
# 75545       05106000  analysis_assim_extend             m3/s    streamflow
# 75546       05106000  analysis_assim_extend             m3/s    streamflow
# 75547       05106000  analysis_assim_extend             m3/s    streamflow
# 75548       05106000  analysis_assim_extend             m3/s    streamflow
# ...              ...                    ...              ...           ...
# 75567       05106000  analysis_assim_extend             m3/s    streamflow
# 75568       05106000  analysis_assim_extend             m3/s    streamflow
# 75569       05106000  analysis_assim_extend             m3/s    streamflow
# 75570       05106000  analysis_assim_extend             m3/s    streamflow
# 75571       05106000  analysis_assim_extend             m3/s    streamflow
#
# [196 rows x 8 columns]
